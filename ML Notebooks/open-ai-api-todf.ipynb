# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import openai
import json

# %%
openai.api_key = "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"
openai.Engine.list()  # check we have authenticated
# Out:
# <OpenAIObject list at 0x7f9473320a90> JSON: {
#   "data": [
#     {
#       "created": null,
#       "id": "whisper-1",
#       "object": "engine",
#       "owner": "openai-internal",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "babbage",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "davinci",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "text-davinci-edit-001",
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true
#     },
#     {
#       "created": null,
#       "id": "babbage-code-search-code",
#       "object": "engine",
#       "owner": "openai-dev",
#       "permissions": null,
#       "ready": true
#     },
#     {
# ...

# %%
MODEL = "gpt-3.5-turbo-0301"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me 20 math questions for a 10-15 year old student with answers and also increase the difficulty after exery 5 questions."},
        {"role": "user", "content": "Give the requested data in json format"}
    ],
    temperature=0,
)

output = response['choices'][0]['message']['content']

def simulate_typing(response_text, typing_speed):
    for char in response_text:
        print(char, end='', flush=True)
        time.sleep(typing_speed)

# Example response text
response_text = output

# Simulate typing with a typing speed of 0.05 seconds per character
typing_speed = 0.05
simulate_typing(response_text, typing_speed)


#print(output)
# Out:
# Sure, here are 20 math questions for a 10-15 year old student with answers in JSON format:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12
#     },
#     {
#       "question": "What is 8 x 4?",
#       "answer": 32
#     },
#     {
#       "question": "What is 12 - 6?",
#       "answer": 6
#     },
#     {
#       "question": "What is 3/4 + 1/2?",
#       "answer": 1.25
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8
#     },
#     {
#       "question": "What is 2^3?",
#       "answer": 8
#     },
#     {
#       "question": "What is 15 x 3?",
#       "answer": 45
#     },
#     {
#       "question": "What is 9 - 3 x 2?",
#       "answer": 3
#     },
#     {
#       "question": "What is 1/3 + 2/3?",
#       "answer": 1
#     },
#     {
#       "question": "What is 7^2?",
#       "answer": 49
#     },
#     {
#       "question": "What is 10 x 4?",
#       "answer": 40
#     },
#     {
# ...

# %%
import openai
import json

# Example dummy function hard coded to return the same weather
# In production, this could be your backend API or an external API
def get_current_weather(location, unit="fahrenheit"):
    """Get the current weather in a given location"""
    weather_info = {
        "location": location,
        "temperature": "72",
        "unit": unit,
        "forecast": ["sunny", "windy"],
    }
    return json.dumps(weather_info)

# Step 1, send model the user query and what functions it has access to
def run_conversation():
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0613",
        messages=[{"role": "user", "content": "What's the weather like in Dublin, Ireland?"}],
        functions=[
            {
                "name": "get_current_weather",
                "description": "Get the current weather in a given location",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "location": {
                            "type": "string",
                            "description": "The city and state, e.g. San Francisco, CA",
                        },
                        "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
                    },
                    "required": ["location"],
                },
            }
        ],
        function_call="auto",
    )

    message = response["choices"][0]["message"]

    # Step 2, check if the model wants to call a function
    if message.get("function_call"):
        function_name = message["function_call"]["name"]

        # Step 3, call the function
        # Note: the JSON response from the model may not be valid JSON
        function_response = get_current_weather(
            location=message.get("location"),
            unit=message.get("unit"),
        )

        # Step 4, send model the info on the function call and function response
        second_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0613",
            messages=[
                {"role": "user", "content": "What is the weather like in boston?"},
                message,
                {
                    "role": "function",
                    "name": function_name,
                    "content": function_response,
                },
            ],
        )
        return second_response

print(run_conversation())
# Out:
# {
#   "id": "chatcmpl-7RWpwRO6doiYBWe4oOsfGbG9LaodZ",
#   "object": "chat.completion",
#   "created": 1686795436,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "I apologize, but I am currently unable to provide real-time weather updates for specific locations. However, based on the latest data I have, the weather in Dublin, Ireland is currently sunny and windy with a temperature of 72 degrees. If you are inquiring about the weather in Boston, please check a trusted weather website or use a weather app for the most up-to-date information."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 70,
#     "completion_tokens": 77,
#     "total_tokens": 147
#   }
# }

# %%
import time

def simulate_typing(response_text, typing_speed):
    for char in response_text:
        print(char, end='', flush=True)
        time.sleep(typing_speed)

# Example response text
response_text = "This is the response generated by the OpenAI model."

# Simulate typing with a typing speed of 0.05 seconds per character
typing_speed = 0.05
simulate_typing(response_text, typing_speed)
# Out:
# This is the response generated by the OpenAI model.

# %%
# Parse the JSON-like output
data = json.loads()

# Extract the questions and answers from the parsed data
questions = [q['question'] for q in data['questions']]
answers = [q['answer'] for q in data['questions']]

# Create a dataframe with the questions and answers
df = pd.DataFrame({"Question": questions, "Answer": answers})

# Print the dataframe
print(df)
# Out:
# Sure, here are 20 math questions for a 10-15 year old student with answers in JSON format:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12
#     },
#     {
#       "question": "What is 8 x 4?",
#       "answer": 32
#     },
#     {
#       "question": "What is 12 - 6?",
#       "answer": 6
#     },
#     {
#       "question": "What is 3/4 + 1/2?",
#       "answer": 1.25
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8
#     },
#     {
#       "question": "What is 2^3?",
#       "answer": 8
#     },
#     {
#       "question": "What is 15 x 3?",
#       "answer": 45
#     },
#     {
#       "question": "What is 9 - 3 x 2?",
#       "answer": 3
#     },
#     {
#       "question": "What is 1/3 + 2/3?",
#       "answer": 1
#     },
#     {
#       "question": "What is 7^2?",
#       "answer": 49
#     },
#     {
#       "question": "What is 10 x 4?",
#       "answer": 40
#     },
#     {
# ...

# %%
MODEL = "gpt-3.5-turbo-0301"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me 20 math questions for a 10-15 year old student with answers and also increase the difficulty after every 5 questions."},
        {"role": "user", "content": "Give the requested data in json format"}
    ],
    temperature=0,
)
output = response['choices'][0]['message']['content']
print("Output:", output)
# Out:
# Output: Sure, here's an example of what the JSON data could look like:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12
#     },
#     {
#       "question": "What is 10 - 3?",
#       "answer": 7
#     },
#     {
#       "question": "What is 4 x 6?",
#       "answer": 24
#     },
#     {
#       "question": "What is 18 / 3?",
#       "answer": 6
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8
#     },
#     {
#       "question": "What is 3 to the power of 4?",
#       "answer": 81
#     },
#     {
#       "question": "What is 15 + 23?",
#       "answer": 38
#     },
#     {
#       "question": "What is 9 x 8?",
#       "answer": 72
#     },
#     {
#       "question": "What is 25 / 5?",
#       "answer": 5
#     },
#     {
#       "question": "What is the value of pi?",
#       "answer": 3.14159265359
#     },
#     {
#       "question": "What is 12 + 17?",
#       "answer": 29
#     },
# ...

# %%
def simulate_typing(response_text, typing_speed):
    for char in response_text:
        print(char, end='', flush=True)
        time.sleep(typing_speed)

# Example response text
response_text = output

# Simulate typing with a typing speed of 0.05 seconds per character
typing_speed = 0.05
simulate_typing(response_text, typing_speed)
# Out:
# Sure, here's an example of what the JSON data could look like:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12
#     },
#     {
#       "question": "What is 9 - 3?",
#       "answer": 6
#     },
#     {
#       "question": "What is 4 x 6?",
#       "answer": 24
#     },
#     {
#       "question": "What is 18 / 3?",
#       "answer": 6
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8
#     },
#     {
#       "question": "What is 3^4?",
#       "answer": 81
#     },
#     {
#       "question": "What is 2/3 + 1/4?",
#       "answer": 11/12
#     },
#     {
#       "question": "What is 7/8 - 3/4?",
#       "answer": 1/8
#     },
#     {
#       "question": "What is 2/5 x 3/4?",
#       "answer": 3/10
#     },
#     {
#       "question": "What is 5/6 ÷ 2/3?",
#       "answer": 5/4
#     },
#     {
#       "question": "What is 2^5?",
#       "answer": 32
#     },
#     {
# ...

# %%
data = json.dumps(json_data, indent=2)

# %%
import pandas as pd
import json

# Read JSON data from a file
with open('data.json', 'r') as file:
    json_data = file.read()

# Parse the JSON data
data = json.loads(json_data)

# Convert the JSON data to a dataframe
df = pd.DataFrame(data['questions'])

# Print the datafr
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 5
#       2 import json
#       4 # Read JSON data from a file
# ----> 5 with open('data.json', 'r') as file:
#       6     json_data = file.read()
#       8 # Parse the JSON data
#
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.json'

# %%
import openai

MODEL = "gpt-3.5-turbo-0301"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me 20 math questions for a 10-15 year old student with answers and also increase the difficulty after every 5 questions."},
        {"role": "user", "content": "Give the requested data in json format"}
    ],
    temperature=0,
)
output = response['choices'][0]['message']['content']
print("Output:", output)

# Store the output in a file
with open("output.txt", "w") as file:
    file.write(output)
# Out:
# Output: Sure, here's an example of 20 math questions in JSON format:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12
#     },
#     {
#       "question": "What is 8 x 3?",
#       "answer": 24
#     },
#     {
#       "question": "What is 12 - 6?",
#       "answer": 6
#     },
#     {
#       "question": "What is 9 / 3?",
#       "answer": 3
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8
#     },
#     {
#       "question": "What is 3 to the power of 4?",
#       "answer": 81
#     },
#     {
#       "question": "What is 15 + 23?",
#       "answer": 38
#     },
#     {
#       "question": "What is 7 x 9?",
#       "answer": 63
#     },
#     {
#       "question": "What is 18 - 9?",
#       "answer": 9
#     },
#     {
#       "question": "What is 12 / 4?",
#       "answer": 3
#     },
#     {
#       "question": "What is the square root of 81?",
#       "answer": 9
#     },
#     {
# ...

# %%
import openai

MODEL = "gpt-3.5-turbo-0301"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me a mathematically correct and quick response ."},
        {"role": "user", "content": "Give me 50 math questions for a 10-15 year old student with answers and also with different difficulty level."},
        {"role": "user", "content": "Give the requested data in json format"},
        #{"role": "user", "content": "Give me a quick response for (Give me 20 math questions for a 10-15 year old student and answers. Also increase the difficulty after every 5 questions.) "}
    ],
    temperature=0,
)
output = response['choices'][0]['message']['content']
print("Output:", output)

# Store the output in a file
with open("output.txt", "w") as file:
    file.write(output)
# Out:
# Output: Here is an example of how the data could be formatted in JSON:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 5 + 7?",
#       "answer": 12,
#       "difficulty": "easy"
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8,
#       "difficulty": "medium"
#     },
#     {
#       "question": "What is the value of x in the equation 2x + 5 = 15?",
#       "answer": 5,
#       "difficulty": "hard"
#     },
#     {
#       "question": "What is the area of a rectangle with length 6 and width 4?",
#       "answer": 24,
#       "difficulty": "easy"
#     },
#     {
#       "question": "What is the value of pi to two decimal places?",
#       "answer": 3.14,
#       "difficulty": "medium"
#     },
#     {
#       "question": "What is the slope of the line passing through the points (2, 3) and (4, 5)?",
#       "answer": 1,
#       "difficulty": "hard"
#     },
#     {
#       "question": "What is the product of 6 and 7?",
# ...

# %%
import openai
import json

MODEL = "gpt-3.5-turbo-0301"
response = openai.ChatCompletion.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me a mathematically correct and quick response."},
        {"role": "user", "content": "Give me 100 math questions for a 10-15 year old student with answers and also with different difficulty level."},
        {"role": "user", "content": "Give the requested data in json format"},
    ],
    temperature=0,
)
output = response['choices'][0]['message']['content']
print("Output:", output)

# Extract the JSON part from the output
json_start_index = output.find('{')
json_end_index = output.rfind('}')
json_data = output[json_start_index:json_end_index+1]

# Format the JSON data with indentation
formatted_data = json.dumps(json.loads(json_data), indent=2)

# Save the formatted JSON data to a file
with open("output1.json", "w") as file:
    file.write(formatted_data)
# Out:
# Output: Here is an example of how the data could be formatted in JSON:
#
# ```
# {
#   "questions": [
#     {
#       "question": "What is 2 + 2?",
#       "answer": 4,
#       "difficulty": "easy"
#     },
#     {
#       "question": "What is the square root of 64?",
#       "answer": 8,
#       "difficulty": "medium"
#     },
#     {
#       "question": "What is the value of x in the equation 3x + 5 = 14?",
#       "answer": 3,
#       "difficulty": "hard"
#     },
#     {
#       "question": "What is the area of a rectangle with length 6 and width 4?",
#       "answer": 24,
#       "difficulty": "easy"
#     },
#     {
#       "question": "What is the value of pi to two decimal places?",
#       "answer": 3.14,
#       "difficulty": "medium"
#     },
#     {
#       "question": "What is the slope of the line y = 2x + 3?",
#       "answer": 2,
#       "difficulty": "hard"
#     },
#     {
#       "question": "What is the product of 7 and 9?",
#       "answer": 63,
# ...

# %%
# Read the JSON file into a DataFrame
df5 = pd.read_json('output.json')

# Print the DataFrame
df5
# Out:
#                                             questions
# 0   {'question': 'What is 2 + 2?', 'answer': 4, 'd...
# 1   {'question': 'What is the square root of 64?',...
# 2   {'question': 'What is the value of x in the eq...
# 3   {'question': 'What is the area of a rectangle ...
# 4   {'question': 'What is the value of pi to two d...
# 5   {'question': 'What is the slope of the line y ...
# 6   {'question': 'What is the product of 7 and 9?'...
# 7   {'question': 'What is the value of y in the eq...
# 8   {'question': 'What is the volume of a sphere w...
# 9   {'question': 'What is the sum of the first 10 ...
# 10  {'question': 'What is the value of x in the eq...
# 11  {'question': 'What is the length of the hypote...
# 12  {'question': 'What is the quotient of 24 and 6...
# 13  {'question': 'What is the value of y in the eq...
# 14  {'question': 'What is the circumference of a c...
# 15  {'question': 'What is the sum of the first 15 ...
# ...

# %%
import json
import pandas as pd

# Output data
output = ''' 
{
  "questions": [
    {
      "question": "What is 2 + 2?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the square root of 64?",
      "answer": 8,
      "difficulty": "medium"
    },
    {
      "question": "What is the value of x in the equation 3x + 5 = 14?",
      "answer": 3,
      "difficulty": "hard"
    },
    {
      "question": "What is the area of a rectangle with length 6 and width 4?",
      "answer": 24,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of pi to two decimal places?",
      "answer": 3.14,
      "difficulty": "medium"
    },
    {
      "question": "What is the slope of the line y = 2x + 3?",
      "answer": 2,
      "difficulty": "hard"
    },
    {
      "question": "What is the product of 7 and 9?",
      "answer": 63,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 2y - 4 = 10?",
      "answer": 7,
      "difficulty": "medium"
    },
    {
      "question": "What is the volume of a sphere with radius 5?",
      "answer": 523.6,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 10 even numbers?",
      "answer": 110,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 2x + 3 = 11?",
      "answer": 4,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the hypotenuse of a right triangle with legs of length 3 and 4?",
      "answer": 5,
      "difficulty": "hard"
    },
    {
      "question": "What is the quotient of 24 and 6?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 3y - 7 = 8?",
      "answer": 5,
      "difficulty": "medium"
    },
    {
      "question": "What is the circumference of a circle with radius 2?",
      "answer": 12.57,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 15 odd numbers?",
      "answer": 225,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 4x - 5 = 11?",
      "answer": 4,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the diagonal of a square with side length 7?",
      "answer": 9.9,
      "difficulty": "hard"
    },
    {
      "question": "What is the product of 5 and 12?",
      "answer": 60,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 5y + 2 = 27?",
      "answer": 5,
      "difficulty": "medium"
    },
    {
      "question": "What is the area of a circle with radius 3?",
      "answer": 28.27,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 20 even numbers?",
      "answer": 420,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 3x - 4 = 8?",
      "answer": 4,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the hypotenuse of a right triangle with legs of length 5 and 12?",
      "answer": 13,
      "difficulty": "hard"
    },
    {
      "question": "What is the quotient of 36 and 9?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 4y - 3 = 13?",
      "answer": 4,
      "difficulty": "medium"
    },
    {
      "question": "What is the circumference of a circle with radius 4?",
      "answer": 25.13,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 25 odd numbers?",
      "answer": 625,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 5x + 2 = 27?",
      "answer": 5,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the diagonal of a square with side length 10?",
      "answer": 14.14,
      "difficulty": "hard"
    },
    {
      "question": "What is the product of 8 and 7?",
      "answer": 56,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 6y - 5 = 19?",
      "answer": 4,
      "difficulty": "medium"
    },
    {
      "question": "What is the area of a circle with radius 5?",
      "answer": 78.54,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 30 even numbers?",
      "answer": 900,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 6x - 3 = 33?",
      "answer": 6,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the hypotenuse of a right triangle with legs of length 8 and 15?",
      "answer": 17,
      "difficulty": "hard"
    },
    {
      "question": "What is the quotient of 48 and 12?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 7y + 4 = 39?",
      "answer": 5,
      "difficulty": "medium"
    },
    {
      "question": "What is the circumference of a circle with radius 6?",
      "answer": 37.7,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 35 odd numbers?",
      "answer": 1225,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 7x - 2 = 45?",
      "answer": 7,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the diagonal of a square with side length 15?",
      "answer": 21.21,
      "difficulty": "hard"
    },
    {
      "question": "What is the product of 9 and 6?",
      "answer": 54,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 8y - 7 = 17?",
      "answer": 3,
      "difficulty": "medium"
    },
    {
      "question": "What is the area of a circle with radius 7?",
      "answer": 153.94,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 40 even numbers?",
      "answer": 1600,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 8x + 5 = 69?",
      "answer": 8,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the hypotenuse of a right triangle with legs of length 10 and 24?",
      "answer": 26,
      "difficulty": "hard"
    },
    {
      "question": "What is the quotient of 60 and 15?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 9y - 8 = 64?",
      "answer": 8,
      "difficulty": "medium"
    },
    {
      "question": "What is the circumference of a circle with radius 8?",
      "answer": 50.27,
      "difficulty": "hard"
    },
    {
      "question": "What is the sum of the first 45 odd numbers?",
      "answer": 2025,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of x in the equation 9x - 4 = 76?",
      "answer": 8,
      "difficulty": "medium"
    },
    {
      "question": "What is the length of the diagonal of a square with side length 20?",
      "answer": 28.28,
      "difficulty": "hard"
    },
    {
      "question": "What is the product of 10 and 5?",
      "answer": 50,
      "difficulty": "easy"
    },
    {
      "question": "What is the value of y in the equation 10y + 3 = 73?",
      "answer": 7,
      "difficulty": "medium"
    },
    {
      "question": "What is the area of a circle with radius 10?",
      "answer": 314.16,
      "difficulty": "hard"
    }
  ]
}
'''

# Extract the JSON part from the output
json_start_index = output.find('{')
json_end_index = output.rfind('}')
json_data = output[json_start_index:json_end_index+1]

# Parse the JSON data
data = json.loads(json_data)

# Convert the JSON data to a dataframe
df5 = pd.DataFrame(data['questions'])

# Print the dataframe
df5
# Out:
#                                              question   answer difficulty
# 0                                      What is 2 + 2?     4.00       easy
# 1                      What is the square root of 64?     8.00     medium
# 2   What is the value of x in the equation 3x + 5 ...     3.00       hard
# 3   What is the area of a rectangle with length 6 ...    24.00       easy
# 4      What is the value of pi to two decimal places?     3.14     medium
# 5           What is the slope of the line y = 2x + 3?     2.00       hard
# 6                     What is the product of 7 and 9?    63.00       easy
# 7   What is the value of y in the equation 2y - 4 ...     7.00     medium
# 8       What is the volume of a sphere with radius 5?   523.60       hard
# 9       What is the sum of the first 10 even numbers?   110.00       easy
# 10  What is the value of x in the equation 2x + 3 ...     4.00     medium
# 11  What is the length of the hypotenuse of a righ...     5.00       hard
# ...

# %%
df1
# Assuming you have a DataFrame named 'df' with 'question', 'answer', and 'difficulty' columns
# df = ...

# Create a dictionary mapping numbers to labels
difficulty_mapping = {1: 'Easy', 2: 'Easy', 3: 'Medium', 4: 'Medium', 5: 'Hard'}

# Replace the numbers in the 'difficulty' column with labels using the mapping dictionary
df1['difficulty'] = df1['difficulty'].replace(difficulty_mapping)

# Print the modified DataFrame
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/3224662155.py in <module>
# ----> 1 df1
#       2 # Assuming you have a DataFrame named 'df' with 'question', 'answer', and 'difficulty' columns
#       3 # df = ...
#       4
#       5 # Create a dictionary mapping numbers to labels
#
# NameError: name 'df1' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/3882145664.py in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/1715873167.py in <module>
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
result = pd.concat([df1, df2, df3, df4, df5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/619884257.py in <module>
# ----> 1 result = pd.concat([df1, df2, df3, df4, df5])
#
# NameError: name 'pd' is not defined

# %%
result
# Out:
#                                              question    answer difficulty
# 0                                      What is 2 + 2?         4       Easy
# 1                      What is the square root of 64?         8       Easy
# 2                                      What is 3 x 5?        15       Easy
# 3                            What is the value of pi?  3.141593       Easy
# 4   What is the next number in the sequence: 1, 3,...         9       Easy
# ..                                                ...       ...        ...
# 52  What is the value of x in the equation 9x - 4 ...       8.0     medium
# 53  What is the length of the diagonal of a square...     28.28       hard
# 54                   What is the product of 10 and 5?      50.0       easy
# 55  What is the value of y in the equation 10y + 3...       7.0     medium
# 56       What is the area of a circle with radius 10?    314.16       hard
#
# [229 rows x 3 columns]

# %%
import json

# Open the JSON file
with open('final.json', 'r') as file:
    file_json = json.load(file)

# Print the JSON data
print(file_json)
# Out:
# [{'question': 'What is 2 + 2?', 'answer': 4, 'difficulty': 'Easy'}, {'question': 'What is the square root of 64?', 'answer': 8, 'difficulty': 'Easy'}, {'question': 'What is 3 x 5?', 'answer': 15, 'difficulty': 'Easy'}, {'question': 'What is the value of pi?', 'answer': 3.1415926536, 'difficulty': 'Easy'}, {'question': 'What is the next number in the sequence: 1, 3, 5, 7, ...?', 'answer': 9, 'difficulty': 'Easy'}, {'question': 'What is 10% of 200?', 'answer': 20, 'difficulty': 'Easy'}, {'question': 'What is the area of a rectangle with length 6 and width 4?', 'answer': 24, 'difficulty': 'Easy'}, {'question': 'What is the slope of the line y = 2x + 3?', 'answer': 2, 'difficulty': 'Easy'}, {'question': 'What is the value of x in the equation 2x + 5 = 11?', 'answer': 3, 'difficulty': 'Easy'}, {'question': 'What is the next number in the sequence: 1, 4, 9, 16, ...?', 'answer': 25, 'difficulty': 'Easy'}, {'question': 'What is the value of x in the equation 3x - 7 = 8x + 5?', 'answer': -3, 
# ...

# %%
# Convert DataFrame to JSON
final_json = result.to_json(orient='records')

# Print the JSON data
print(final_json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/2847612170.py in <module>
#       1 # Convert DataFrame to JSON
# ----> 2 final_json = result.to_json(orient='records')
#       3
#       4 # Print the JSON data
#       5 print(final_json)
#
# NameError: name 'result' is not defined

# %%
result.to_json('final.json', orient='records')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/207107277.py in <module>
# ----> 1 result.to_json('final.json', orient='records')
#
# NameError: name 'result' is not defined

# %%
# Set up the Cosmos DB client
endpoint_uri = "https://its-project.documents.azure.com:443/"
primary_key = "x2KUHjL3C23D4n2nR9ebCgdi3Wh8i8h92KYodwCGRYI1ryVX6io7zpP3eNH6f1ZA0U0qnbdrkBfGACDbTHnmwg=="
client = CosmosClient(endpoint_uri, primary_key)

# %%
# Get a reference to the database and container
database_name = "testsqldb"
container_name = "testpartion1"
database = client.get_database_client(database_name)
container = database.get_container_client(container_name)

# %%
short_result = '''{'question': 'What is 2 + 2?', 'answer': 4, 'difficulty': 'Easy'}, {'question': 'What is the square root of 64?', 'answer': 8, 'difficulty': 'Easy'}, {'question': 'What is 3 x 5?', 'answer': 15, 'difficulty': 'Easy'}, {'question': 'What is the value of pi?', 'answer': 3.1415926536, 'difficulty': 'Easy'}, {'question': 'What is the next number in the sequence: 1, 3, 5, 7, ...?', 'answer': 9, 'difficulty': 'Easy'}, {'question': 'What is 10% of 200?', 'answer': 20, 'difficulty': 'Easy'}'''

# %%
data = '''
{
    {
      "question": "What is 2 + 2?",
      "answer": 4,
      "difficulty": "easy"
    },
    {
      "question": "What is the square root of 64?",
      "answer": 8,
      "difficulty": "medium"
    },
    {
      "question": "What is the value of x in the equation 3x + 5 = 14?",
      "answer": 3,
      "difficulty": "hard"
    }
}
'''

# %%
df_test = pd.DataFrame(short_result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/4288872191.py in <module>
# ----> 1 df_test = pd.DataFrame(short_result)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
# Open the JSON file and load the data
with open("final.json", "r") as file:
    json_data = json.load(file)

# Save the data to a different JSON file with proper indentation
with open("final1.json", "w") as file:
    json.dump(json_data, file, indent=4)

# %%
# Extract the JSON part from the output
json_start_index = data.find('{')
json_end_index = data.rfind('}')
json_data = data[json_start_index:json_end_index+1]

# Parse the JSON data
data1 = json.loads(json_data)

# Convert the JSON data to a dataframe
df_test = pd.DataFrame(data1)

# Print the dataframe
df_test
# Out:
#                                            questions
# 0  {'question': 'What is 2 + 2?', 'answer': 4, 'd...
# 1  {'question': 'What is the square root of 64?',...
# 2  {'question': 'What is the value of x in the eq...

# %%
df_test.to_json(test.json, )

# %%
# Convert DataFrame to JSON
json_data1 = df_test.to_json(orient='records')

# Print the JSON data
print(json_data1)
# Out:
# [{"questions":{"question":"What is 2 + 2?","answer":4,"difficulty":"easy"}},{"questions":{"question":"What is the square root of 64?","answer":8,"difficulty":"medium"}},{"questions":{"question":"What is the value of x in the equation 3x + 5 = 14?","answer":3,"difficulty":"hard"}}]

# %%
data = {
        "question": "What is 2 + 2?",
        "answer": 4,
        "difficulty": "easy";
        "question": "What is the square root of 64?",
        "answer": 8,
        "difficulty": "medium";
        "question": "What is the value of x in the equation 3x + 5 = 14?",
        "answer": 3,
        "difficulty": "hard"
    }
# Out:
#   File "/var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/2809634634.py", line 4
#     "difficulty": "easy";
#                         ^
# SyntaxError: invalid syntax

# %%
json_data = json.dumps(data)

print(json_data)

# Save the JSON data to a file
with open("dummy.json", "w") as file:
    file.write(json_data)
# Out:
# [{"question": "What is 2 + 2?", "answer": 4, "difficulty": "easy"}, {"question": "What is the square root of 64?", "answer": 8, "difficulty": "medium"}, {"question": "What is the value of x in the equation 3x + 5 = 14?", "answer": 3, "difficulty": "hard"}]

# %%
format_data = json.dumps(json.loads(json_data), indent=2)

# %%
json_data
# Out:
# [{'question': 'What is 2 + 2?', 'answer': 4, 'difficulty': 'Easy'},
#  {'question': 'What is the square root of 64?',
#   'answer': 8,
#   'difficulty': 'Easy'},
#  {'question': 'What is 3 x 5?', 'answer': 15, 'difficulty': 'Easy'},
#  {'question': 'What is the value of pi?',
#   'answer': 3.1415926536,
#   'difficulty': 'Easy'},
#  {'question': 'What is the next number in the sequence: 1, 3, 5, 7, ...?',
#   'answer': 9,
#   'difficulty': 'Easy'},
#  {'question': 'What is 10% of 200?', 'answer': 20, 'difficulty': 'Easy'},
#  {'question': 'What is the area of a rectangle with length 6 and width 4?',
#   'answer': 24,
#   'difficulty': 'Easy'},
#  {'question': 'What is the slope of the line y = 2x + 3?',
#   'answer': 2,
#   'difficulty': 'Easy'},
#  {'question': 'What is the value of x in the equation 2x + 5 = 11?',
#   'answer': 3,
#   'difficulty': 'Easy'},
#  {'question': 'What is the next number in the sequence: 1, 4, 9, 16, ...?',
#   'answer': 25,
#   'difficulty': 'Easy'},
# ...

# %%
with open("dummy1.json", "w") as file:
    file.write(format_data)

# %%
container.create_item(body=format_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/3452553553.py in <module>
# ----> 1 container.create_item(body=format_data)
#
# /opt/anaconda3/lib/python3.9/site-packages/azure/core/tracing/decorator.py in wrapper_use_tracer(*args, **kwargs)
#      74             span_impl_type = settings.tracing_implementation()
#      75             if span_impl_type is None:
# ---> 76                 return func(*args, **kwargs)
#      77
#      78             # Merge span is parameter is set, but only if no explicit parent are passed
#
# /opt/anaconda3/lib/python3.9/site-packages/azure/cosmos/container.py in create_item(self, body, populate_query_metrics, pre_trigger_include, post_trigger_include, indexing_directive, **kwargs)
#     564             request_options["indexingDirective"] = indexing_directive
#     565
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/3048952558.py in <module>
# ----> 1 data.dtypes
#
# AttributeError: 'list' object has no attribute 'dtypes'

# %%
json_data1
# Out:
# '[{"questions":{"question":"What is 2 + 2?","answer":4,"difficulty":"easy"}},{"questions":{"question":"What is the square root of 64?","answer":8,"difficulty":"medium"}},{"questions":{"question":"What is the value of x in the equation 3x + 5 = 14?","answer":3,"difficulty":"hard"}}]'

# %%
format_data1 = json.dumps(json.loads(json_data1), indent=2)

# %%
format_data1
# Out:
# '[\n  {\n    "questions": {\n      "question": "What is 2 + 2?",\n      "answer": 4,\n      "difficulty": "easy"\n    }\n  },\n  {\n    "questions": {\n      "question": "What is the square root of 64?",\n      "answer": 8,\n      "difficulty": "medium"\n    }\n  },\n  {\n    "questions": {\n      "question": "What is the value of x in the equation 3x + 5 = 14?",\n      "answer": 3,\n      "difficulty": "hard"\n    }\n  }\n]'

# %%
filepath = "/Users/rahulkantode/Desktop/Term Project/ML notebooks/final1.json"

# %%
df = pd.read_json('/Users/rahulkantode/Desktop/Term Project/ML notebooks/final1.json')

# %%
df.insert(0, 'id', range(1, len(df) + 1))

# %%
df
# Out:
#       id                                           question    answer  \
# 0      1                                     What is 2 + 2?         4
# 1      2                     What is the square root of 64?         8
# 2      3                                     What is 3 x 5?        15
# 3      4                           What is the value of pi?  3.141593
# 4      5  What is the next number in the sequence: 1, 3,...         9
# ..   ...                                                ...       ...
# 224  225  What is the value of x in the equation 9x - 4 ...       8.0
# 225  226  What is the length of the diagonal of a square...     28.28
# 226  227                   What is the product of 10 and 5?      50.0
# 227  228  What is the value of y in the equation 10y + 3...       7.0
# 228  229       What is the area of a circle with radius 10?    314.16
#
#     difficulty
# 0         Easy
# 1         Easy
# 2         Easy
# 3         Easy
# 4         Easy
# ..         ...
# ...

# %%
upload_data = df.to_json(orient='records')

# %%
db_data = json.loads(upload_data)

# %%
db_data
# Out:
# [{'id': 1, 'question': 'What is 2 + 2?', 'answer': 4, 'difficulty': 'Easy'},
#  {'id': 2,
#   'question': 'What is the square root of 64?',
#   'answer': 8,
#   'difficulty': 'Easy'},
#  {'id': 3, 'question': 'What is 3 x 5?', 'answer': 15, 'difficulty': 'Easy'},
#  {'id': 4,
#   'question': 'What is the value of pi?',
#   'answer': 3.1415926536,
#   'difficulty': 'Easy'},
#  {'id': 5,
#   'question': 'What is the next number in the sequence: 1, 3, 5, 7, ...?',
#   'answer': 9,
#   'difficulty': 'Easy'},
#  {'id': 6,
#   'question': 'What is 10% of 200?',
#   'answer': 20,
#   'difficulty': 'Easy'},
#  {'id': 7,
#   'question': 'What is the area of a rectangle with length 6 and width 4?',
#   'answer': 24,
#   'difficulty': 'Easy'},
#  {'id': 8,
#   'question': 'What is the slope of the line y = 2x + 3?',
#   'answer': 2,
#   'difficulty': 'Easy'},
#  {'id': 9,
#   'question': 'What is the value of x in the equation 2x + 5 = 11?',
#   'answer': 3,
#   'difficulty': 'Easy'},
# ...

# %%
ENDPOINT = "https://its-project.documents.azure.com:443/"
MASTERKEY = "x2KUHjL3C23D4n2nR9ebCgdi3Wh8i8h92KYodwCGRYI1ryVX6io7zpP3eNH6f1ZA0U0qnbdrkBfGACDbTHnmwg=="
DATABASE_ID = 'your_database_id'
CONTAINER_ID = 'your_container_id'

# %%
database_link = 'dbs/' + DATABASE_ID

# %%
container_link = database_link + '/colls/' + CONTAINER_ID

# %%
for item in items:
    container.upsert_item(item)
# Out:
# ---------------------------------------------------------------------------
# CosmosHttpResponseError                   Traceback (most recent call last)
# /var/folders/rf/pzhqbq2n7pz30v1xdcc4hl8h0000gn/T/ipykernel_27189/3367586458.py in <module>
#       1 for item in items:
# ----> 2     container.upsert_item(item)
#
# /opt/anaconda3/lib/python3.9/site-packages/azure/core/tracing/decorator.py in wrapper_use_tracer(*args, **kwargs)
#      74             span_impl_type = settings.tracing_implementation()
#      75             if span_impl_type is None:
# ---> 76                 return func(*args, **kwargs)
#      77
#      78             # Merge span is parameter is set, but only if no explicit parent are passed
#
# /opt/anaconda3/lib/python3.9/site-packages/azure/cosmos/container.py in upsert_item(self, body, populate_query_metrics, pre_trigger_include, post_trigger_include, **kwargs)
#     506             request_options["postTriggerInclude"] = post_trigger_include
#     507
# ...
